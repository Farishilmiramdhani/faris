# %% [markdown]
# ### Import Package

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Mathplotplib

# %%
plt.plot();

# %%
plt.plot([10, 20, 30, 40, 50]);

# %%
x = [10, 20, 30, 40, 50]
y = np.array(x)**2

# %%
x
# Out:
# [10, 20, 30, 40, 50]

# %%
y
# Out:
# array([ 100,  400,  900, 1600, 2500])

# %%
plt.plot(x, y);

# %%
plt.plot(x, y)
plt.xlabel('Sumbu x')
plt.ylabel('Sumbu y')
plt.title('Data Penyakit');

# %%
plt.subplot(221)
plt.plot(x, y, color='blue')
plt.xlabel('Sumbu x')
plt.ylabel('Sumbu y')
         
plt.subplot(222)
plt.plot(y, x, color='red')
plt.xlabel('Sumbu x2')
plt.ylabel('Sumbu y2')
plt.tight_layout()
plt.show()

# %%
x = np.linspace(0, 10, 100)
y = np.sqrt(x)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([0.        , 0.31782086, 0.44946657, 0.55048188, 0.63564173,
#        0.71066905, 0.77849894, 0.84087497, 0.89893315, 0.95346259,
#        1.00503782, 1.05409255, 1.10096377, 1.14591942, 1.18917678,
#        1.23091491, 1.27128345, 1.31040899, 1.34839972, 1.38534902,
#        1.42133811, 1.45643816, 1.49071198, 1.52421531, 1.55699789,
#        1.58910432, 1.62057478, 1.65144565, 1.68174993, 1.71151773,
#        1.74077656, 1.76955168, 1.7978663 , 1.82574186, 1.85319816,
#        1.88025358, 1.90692518, 1.93322884, 1.95917938, 1.98479065,
#        2.01007563, 2.03504647, 2.0597146 , 2.08409077, 2.10818511,
#        2.13200716, 2.15556597, 2.17887006, 2.20192753, 2.22474604,
#        2.24733287, 2.26969495, 2.29183884, 2.31377081, 2.33549683,
#        2.3570226 , 2.37835356, 2.3994949 , 2.42045158, 2.44122837,
#        2.46182982, 2.48226029, 2.50252398, 2.5226249 , 2.5425669 ,
#        2.56235372, 2.5819889 , 2.60147588, 2.62081798, 2.64001837,
# ...

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, y);

# %%
y1 = np.sin(x)
y2 = np.cos(x)

# %%
figure = plt.figure()
ax = plt.axes ()
ax.plot(x, y1)
ax.plot(x, y2);

# %%
df = pd.read_csv('Data/circle_data.csv')
df.head()
# Out:
#                                           x;y;radius
# 0  0.06460799109861874;0.5480280431554418;0.55182...
# 1  -0.27765126786890126;0.42419957415886944;0.506...
# 2  -0.47714576553806887;-0.15748173825206105;0.50...
# 3  0.031218266789752026;-0.16957332276858053;0.17...
# 4  -0.04872401827491005;0.7366319995834587;0.7382...

# %%
df = pd.read_csv('Data/circle_data.csv', sep=';')#memperbaiki data dengan memisahkan colom yang tersambung dengan tanda ';'
df.head()
# Out:
#           x         y    radius
# 0  0.064608  0.548028  0.551823
# 1 -0.277651  0.424200  0.506987
# 2 -0.477146 -0.157482  0.502463
# 3  0.031218 -0.169573  0.172423
# 4 -0.048724  0.736632  0.738242

# %%
a = df.x
b = df.y
rad = df.radius

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(a, b, c='b',s=10 )
plt.axis();

# %%
plt.scatter(a, b, c=rad, s=rad*100, cmap='viridis' )
plt.axis();

# %%
plt.scatter(a, b, c=rad, s=rad*100, cmap='magma' )
plt.axis();

# %% [markdown]
# ### Histogram

# %%
plt.hist(a, bins=40, color='red');

# %% [markdown]
# ## Seaborn

# %%
#menampilkan data 
df= pd.read_csv('Data/linear.csv')
df
# Out:
#             X         y   tipe
# 0    0.490560  3.564196  data1
# 1    0.580862  3.883283  data1
# 2    0.777627  4.485467  data1
# 3    0.193498  2.715008  data1
# 4    0.284830  2.503560  data1
# ..        ...       ...    ...
# 195  0.473481  1.723587  data2
# 196  0.517086  1.812512  data2
# 197  0.215826  1.163678  data2
# 198  0.972825  3.010107  data2
# 199  0.016298  0.506461  data2
#
# [200 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       200 non-null    float64
#  1   y       200 non-null    float64
#  2   tipe    200 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 4.8+ KB

# %%
Data1 = df[df.tipe=='data1']
plt.scatter(df.X, df.y);

# %%
sns.scatterplot(data=df, x='X', y='y');
# Out:
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(data=df, x='X', y='y', hue='tipe');
# Out:
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.lmplot(data=df, x='X', y='y', hue='tipe');
# Out:
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df = pd.read_csv('Data/cereal.csv')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.isna().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.isna(), cmap='inferno');

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.isna(), cmap='inferno');

# %%
df.isna().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.257423
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.024160
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.298074
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.290399
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.380223
# carbo     0.257423 -0.024160 -0.298074  0.290399 -0.380223  1.000000
# sugars    0.566062 -0.281905  0.300552  0.057425 -0.138711 -0.471184
# potass   -0.071991  0.562143  0.197823 -0.042312  0.908647 -0.358557
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.189928
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.138432
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.366427
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.088513
#
#             sugars    potass     shelf    weight      cups    rating
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(numeric_only=True), cmap='Oranges', vmin=-1, vmax=1, annot=True);

# %%
sns.catplot(data=df, x='mfr', kind='count');
# Out:
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.countplot(data=df, x='mfr');
# Out:
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.boxplot(data=df, x='mfr', y='rating');
# Out:
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.barplot(data=df, x='mfr', y='rating', color='blue');
# Out:
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\asani\anaconda3\envs\DSpintar\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
