# %% [markdown]
# ## Mengambil Data API Lewat Kaggle

# %%
import pandas as pd

# %%
# !pip install kaggle

# %%
# !kaggle datasets list -s "goal leagues"
# Out:
# ref                                                      title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# slehkyi/extended-football-stats-for-european-leagues-xg  Football Data: Expected Goals and Other Metrics    1MB  2020-08-02 17:28:39           6190        153  1.0
# shreyanshkhandelwal/goal-dataset-top-5-european-leagues  Goal Dataset - Top 5 European Leagues            174KB  2021-05-23 21:20:09           4667         30  0.5294118
# sanjeetsinghnaik/most-expensive-footballers-2021         Most Expensive Footballers 2021                   13KB  2021-12-03 20:28:03           2256         51  1.0
# ...

# %%
# !kaggle datasets download shreyanshkhandelwal/goal-dataset-top-5-european-leagues
# Out:
# ...
#   0%|          | 0.00/174k [00:00<?, ?B/s]
# 100%|##########| 174k/174k [00:00<00:00, 425kB/s]
# 100%|##########| 174k/174k [00:00<00:00, 423kB/s]

# %%
pd.read_csv("Data/epl-goalScorer(20-21).csv", index_col='Unnamed: 0')
# Out:
#        id             player_name  games  time  goals         xG  assists  \
# 0     647              Harry Kane     35  3097     23  22.174859       14
# 1    1250           Mohamed Salah     37  3085     22  20.250847        5
# 2    1228         Bruno Fernandes     37  3117     18  16.019454       12
# 3     453           Son Heung-Min     37  3139     17  11.023287       10
# 4     822         Patrick Bamford     38  3085     17  18.401863        7
# ..    ...                     ...    ...   ...    ...        ...      ...
# 517  9415  Jaden Philogene-Bidace      1     1      0   0.000000        0
# 518  9423         Gaetano Berardi      2   113      0   0.074761        0
# 519  9524          Anthony Elanga      1    67      0   0.000000        0
# 520  9540             Femi Seriki      1     1      0   0.000000        0
# 521  9552         Tyrese Francois      1    13      0   0.000000        0
#
#             xA  shots  key_passes  yellow_cards  red_cards position  \
# ...

# %% [markdown]
# ## Mengambil Data API Lewat Portal Bandung

# %%
import requests
import json
import tqdm

# %%
ds_list_response = requests.get("http://data.bandung.go.id/api/3/action/package_list")
ds_list_result = json.load(ds_list_response.text)
len(ds_list_result['result']), ds_list_result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 2
#       1 ds_list_response = requests.get("http://data.bandung.go.id/api/3/action/package_list")
# ----> 2 ds_list_result = json.load(ds_list_response.text)
#       3 len(ds_list_result['result']), ds_list_result
#
# File ~\anaconda3\envs\Newpython\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
# ...
